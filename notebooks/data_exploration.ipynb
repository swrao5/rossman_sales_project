# %%
import data_preprocesing
import pandas as pd
import numpy as np
import warnings
from sklearn.model_selection import train_test_split
warnings.filterwarnings("ignore")

# %%
raw_path = r"C:\Users\raosw\projects\rossman_sales_project\data\raw"
preprocessed_path = r"C:\Users\raosw\projects\rossman_sales_project\data\processed"

# %%
df_train, df_test, df_store = data_preprocesing.load_data(raw_path)

# %%
print(df_train.shape)
df_train.head()
# Out:
# (1017209, 9)
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1            0
# 1      2          5 2015-07-31   6064        625     1      1            0
# 2      3          5 2015-07-31   8314        821     1      1            0
# 3      4          5 2015-07-31  13995       1498     1      1            0
# 4      5          5 2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0

# %%
print(df_test.shape)
df_test.head()
# Out:
# (41088, 8)
#    Id  Store  DayOfWeek       Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          4 2015-09-17   1.0      1            0            0.0
# 1   2      3          4 2015-09-17   1.0      1            0            0.0
# 2   3      7          4 2015-09-17   1.0      1            0            0.0
# 3   4      8          4 2015-09-17   1.0      1            0            0.0
# 4   5      9          4 2015-09-17   1.0      1            0            0.0

# %%
df_train_preprocessed, df_test_preprocessed, features_train, features_test = data_preprocesing.preprocess_data(df_train, df_test, df_store, preprocessed_path)

# %%
print(df_train_preprocessed[features_train].shape)
df_train_preprocessed[features_train].head()
# Out:
# (844338, 16)
#    Store  CompetitionDistance  Promo  Promo2  SchoolHoliday  StoreType  \
# 0      1               1270.0      1       0            1.0          3
# 1      2                570.0      1       1            1.0          1
# 2      3              14130.0      1       1            1.0          1
# 3      4                620.0      1       0            1.0          3
# 4      5              29910.0      1       0            1.0          1
#
#    Assortment  StateHoliday  DayOfWeek  Month  Day  Year  WeekOfYear  \
# 0           1             0          4      7   31  2015          31
# 1           1             0          4      7   31  2015          31
# 2           1             0          4      7   31  2015          31
# 3           3             0          4      7   31  2015          31
# 4           1             0          4      7   31  2015          31
#
#    CompetitionOpen  PromoOpen  IsPromoMonth
# 0             82.0       0.00             0
# ...

# %%
print(df_test_preprocessed[features_test].shape)
df_test_preprocessed[features_test].head()
# Out:
# (41088, 16)
#    Store  CompetitionDistance  Promo  Promo2  SchoolHoliday  StoreType  \
# 0      1               1270.0      1       0            0.0          3
# 1      3              14130.0      1       1            0.0          1
# 2      7              24000.0      1       0            0.0          1
# 3      8               7520.0      1       0            0.0          1
# 4      9               2030.0      1       0            0.0          1
#
#    Assortment  StateHoliday  DayOfWeek  Month  Day  Year  WeekOfYear  \
# 0           1             0          3      9   17  2015          38
# 1           1             0          3      9   17  2015          38
# 2           3             0          3      9   17  2015          38
# 3           1             0          3      9   17  2015          38
# 4           3             0          3      9   17  2015          38
#
#    CompetitionOpen  PromoOpen  IsPromoMonth
# 0             84.0        0.0             0
# ...

# %%
df_train_preprocessed[features_train + ['Sales']]
# Out:
#         Store  CompetitionDistance  Promo  Promo2  SchoolHoliday  StoreType  \
# 0           1               1270.0      1       0            1.0          3
# 1           2                570.0      1       1            1.0          1
# 2           3              14130.0      1       1            1.0          1
# 3           4                620.0      1       0            1.0          3
# 4           5              29910.0      1       0            1.0          1
# ...       ...                  ...    ...     ...            ...        ...
# 844333    682                150.0      0       0            1.0          2
# 844334    733                860.0      0       0            1.0          2
# 844335    769                840.0      0       1            1.0          2
# 844336    948               1430.0      0       0            1.0          2
# 844337   1097                720.0      0       0            1.0          2
#
# ...

# %%
train_x, valid_x , train_y, valid_y = train_test_split(df_train_preprocessed[features_train], df_train_preprocessed['Sales'], test_size=0.2, random_state=42)

# %%
print(train_x.shape)
print(valid_x.shape)
print(train_y.shape)
print(valid_y.shape)
# Out:
# (675470, 16)
# (168868, 16)
# (675470,)
# (168868,)
